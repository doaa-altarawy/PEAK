# %%
import numpy as np
import pandas as pd
from os.path import join
from matplotlib import pyplot as plt
# %matplotlib inline


base_dir = '/var/www/DeTangle/DeTangle/netAnalysis/'
sample_chip_file = 'data/DREAM5/Network1/net1_chip_features.tsv'


expr_file = 'data/Roots_li/102715_ave.FPKM.pro.csv'

#-------------------------

# from research gates
# true_file = 'data/Roots_li/finding_missing_predicted.csv'

# from paper figure (predicted)
# paper_figure_table_predicted = 'data/Roots_li/paper_figure_table_cytoscape_predicted.csv'
# final_paper_figure_table_predicted = 'data/Roots_li/processed/paper_figure_table_predicted.csv'

# from paper figure (before) --> original
paper_figure_table_original = 'data/Roots_li/paper_figure_table_original_cytoscape.csv'
final_paper_figure_table_original = 'data/Roots_li/processed/paper_figure_table_original.csv'
final_PK_file = 'data/Roots_li/processed/PK_file.csv'

true_file = final_paper_figure_table_original

#---------------------------------------

gene_names_map = 'data/Roots_li/gene_aliases_20130831.txt'  # downloaded
manual_SL_map = 'data/Roots_li/mapping_SL.csv'              # By Dr. Song Li

# output
final_expr_file = 'data/Roots_li/processed/102715_ave.FPKM.pro.tsv'
final_true_file = 'data/Roots_li/processed/true_edge.txt'
final_true_file_all = 'data/Roots_li/processed/true_edge_all.txt' # including missing
final_tf_file = 'data/Roots_li/processed/root_transcription_factors.tsv'
final_chip_file = 'data/Roots_li/processed/root_chip_features.tsv'

final_mapping = 'data/Roots_li/processed/mapping.csv'
final_gene_ids = 'data/Roots_li/processed/root_gene_ids.tsv'

# %% [markdown]
# # Cystoscape out to edges

# %%
cytoscape_nt = pd.read_csv(paper_figure_table_original)
network = pd.DataFrame(columns=['From', 'To'])

for i,val in enumerate(cytoscape_nt.name):
    temp = val.split(' ')
    network.loc[i] = [temp[0], temp[-1]]

network['edge_type'] = cytoscape_nt['edge_type'].fillna(1)
network.to_csv(final_paper_figure_table_original, header=False, index=False, sep='\t')

network['Predicted'] = cytoscape_nt['Predicted'].fillna(0)
priorKnowledge = network.query('Predicted==0').drop('Predicted', axis=1)
priorKnowledge.to_csv(final_PK_file, header=False, index=False, sep='\t')

priorKnowledge
network
# Out:
#         From        To  edge_type  Predicted
# 0        MGP       SHR        1.0        0.0
# 1        MGP       JKD        1.0        1.0
# 2        MGP       MGP       -1.0        0.0
# 3        MGP      WOX5        1.0        1.0
# 4        ACR      WOX5       -1.0        0.0
# 5        ACR       PHB       -1.0        1.0
# 6        JKD       SHR        1.0        0.0
# 7        JKD       SCR        1.0        0.0
# 8        JKD       MGP        1.0        0.0
# 9        JKD       JKD        1.0        0.0
# 10       PHB       JKD       -1.0        0.0
# 11       PHB       PHB        1.0        1.0
# 12       PHB      WOX5       -1.0        0.0
# 13      IAA5      WOX5       -1.0        0.0
# 14      IAA5       PHB        1.0        1.0
# 15       CLE      WOX5       -1.0        0.0
# 16       CLE       PHB       -1.0        1.0
# 17       CLE       CLE        1.0        1.0
# 18       SHR       SCR        1.0        0.0
# 19       SHR       SHR        1.0        1.0
# 20       SHR       PHB        1.0        1.0
# 21  miRNA165       SHR        1.0        0.0
# 22  miRNA165  miRNA165        1.0        1.0
# 23  miRNA165       PHB       -1.0        0.0
# 24     Auxin      IAA5       -1.0        0.0
# 25     Auxin       PHB       -1.0        1.0
# 26      WOX5      WOX5        1.0        0.0
# 27      WOX5      IAA5        1.0        1.0
# 28      WOX5       PHB        1.0        1.0
# 29       SCR       SCR        1.0        0.0
# 30       SCR  miRNA165        1.0        0.0
# 31       SCR       JKD        1.0        0.0

# %%
mapping = pd.read_csv(gene_names_map, sep='\t')
mapping.fillna('', inplace=True)
# m[m.full_name.str.upper().str.contains('AUXIN')]
mapping.head(2)
# Out:
#   locus_name    symbol full_name
# 0   18S RRNA  18S RRNA
# 1   25S RRNA  25S RRNA

# %%
true = pd.read_csv(true_file, header=None, sep='\t')
all_genes = np.union1d(true[0].unique(), true[1].unique())
# all_genes = np.union1d(all_genes,  ['ARF', 'PLT']) #######################------------------------>>

print(all_genes.shape)
all_genes
# Out:
# (11,)
# array(['ACR', 'Auxin', 'CLE', 'IAA5', 'JKD', 'MGP', 'PHB', 'SCR', 'SHR',
#        'WOX5', 'miRNA165'], dtype=object)

# %%
cols = ['Original_Gene']
cols.extend(mapping.columns)
found = pd.DataFrame(columns=cols)

index = 0
for gene in all_genes:
    values = mapping[mapping.symbol.str.contains(gene)]
    if values.shape[0]>=1:
        for i in values.index:
            v = values.loc[i]
            found.loc[index] = [gene, v.locus_name, v.symbol, v.full_name]
            index +=1
    else:
        found.loc[index] = (gene, '', '', '')
        index +=1

found.to_csv(final_mapping, index=False)
found.head()
# Out:
#   Original_Gene locus_name symbol              full_name
# 0           ACR  AT1G12420   ACR8    ACT domain repeat 8
# 1           ACR  AT1G16880  ACR11  ACT domain repeats 11
# 2           ACR  AT1G69040   ACR4    ACT domain repeat 4
# 3           ACR  AT1G76990   ACR3    ACT domain repeat 3
# 4           ACR  AT2G03730   ACR5    ACT domain repeat 5

# %% [markdown]
# # Override with Manual mapping (Song Li)

# %%
manual_SL_mapping = pd.read_csv(manual_SL_map).fillna('')
# found = manual_SL_mapping.append(found)
found = manual_SL_mapping
print(found.shape)
found
# Out:
# (11, 4)
#    Original_Gene locus_name symbol                         full_name
# 0            ACR  AT1G69040   ACR4               ACT domain repeat 4
# 1          Auxin
# 2            CLE  AT5G12990  CLE40           CLAVATA3/ESR-RELATED 40
# 3           IAA5  AT1G15580   IAA5  indole-3-acetic acid inducible 5
# 4            JKD  AT5G03150    JKD                           JACKDAW
# 5            MGP  AT1G03840    MGP                            Magpie
# 6            PHB  AT2G34710    PHB                         PHABULOSA
# 7            SCR  AT3G54220    SCR                         SCARECROW
# 8            SHR  AT4G37650    SHR                        SHORT ROOT
# 9           WOX5  AT3G11260   WOX5        WUSCHEL related homeobox 5
# 10      miRNA165

# %% [markdown]
# # Sample file formats

# %%
# sample_expr = pd.read_csv(sample_expr_file, sep='\t')
# sample_expr.head(3)

# %%
sample_chip = pd.read_csv(sample_chip_file, sep='\t')
sample_chip.iloc[129:140]
# Out:
#      #Experiment Perturbations PerturbationLevels  Treatment DeletedGenes  \
# 129           41           NaN                NaN        NaN          NaN
# 130           41           NaN                NaN        NaN          NaN
# 131           41            P3                NaN        NaN          NaN
# 132           41            P3                NaN        NaN          NaN
# 133           41            P3                NaN        NaN          NaN
# 134           41            P3                NaN        NaN          NaN
# 135           41            P3                NaN        NaN          NaN
# 136           42            P7               0.80        NaN          NaN
# 137           42            P7               0.80        NaN          NaN
# 138           43           NaN                NaN        NaN          NaN
# 139           43           NaN                NaN        NaN          NaN
#
#     OverexpressedGenes   Time  Repeat
# 129                NaN    NaN       4
# 130                NaN    NaN       5
# 131                NaN    NaN       1
# 132                NaN    NaN       2
# 133                NaN    NaN       3
# 134                NaN    NaN       4
# 135                NaN    NaN       5
# 136                NaN    NaN       1
# 137                NaN    NaN       2
# 138                NaN  150.0       1
# 139                NaN  180.0       1

# %%
# sample_tf = pd.read_csv(sample_tf_file, sep='\t')
# sample_tf.head(3)

# %%
data = pd.read_csv(join(base_dir, expr_file))
data.rename(columns={'Unnamed: 0': 'id'}, inplace=True)
print(data.shape)
data.head(3)
# Out:
# (27368, 23)
#           id        APL        CO2       COBL9        COR        E30  \
# 0  AT5G59170   3.137993   0.455485    2.836957   1.008588   1.320923
# 1  AT5G08160  50.729967  58.267233  142.984667  87.362500  38.599800
# 2  AT4G22890   3.937057   5.503330    0.775913   3.207493   1.757893
#
#          GL2     PET111        S17         S18    ...            SCR  \
# 0   1.161544   1.965928   3.059363    1.774832    ...       2.769333
# 1  82.761833  65.872767  23.722633  112.969633    ...      43.038433
# 2   2.526997   4.083410   6.393837    0.821806    ...       3.140590
#
#          WER        WOL       WOX5       Elong        Mat        Mer  \
# 0   0.724474   1.313954   0.472727    0.084032   0.154675   0.013578
# 1  80.117367  72.309167  38.401067  102.355567  54.907700  48.033200
# 2   2.768607   3.285100  11.819167    2.526157   3.967667   6.565617
#
#          Wrt        CHX       MOCK
# 0   0.037045   0.060743   0.145454
# 1  51.137200  18.095000  47.247367
# 2   5.513927   4.515477   4.592163
#
# [3 rows x 23 columns]

# %%
print(data.shape)
data.apply(lambda x: x.unique().shape, axis=0)
# Out:
# (27368, 23)
# id        (27368,)
# APL       (22542,)
# CO2       (21805,)
# COBL9     (22132,)
# COR       (21198,)
# E30       (22017,)
# GL2       (22327,)
# PET111    (22638,)
# S17       (22504,)
# S18       (21543,)
# S32       (22107,)
# S4        (21388,)
# SCOL      (22233,)
# SCR       (22406,)
# WER       (21958,)
# WOL       (22613,)
# WOX5      (21184,)
# Elong     (22166,)
# Mat       (22230,)
# Mer       (22072,)
# Wrt       (22849,)
# CHX       (23122,)
# MOCK      (22299,)
# dtype: object

# %%
data.apply(lambda x: x.isnull().sum(), axis=0)
# Out:
# id        0
# APL       0
# CO2       0
# COBL9     0
# COR       0
# E30       0
# GL2       0
# PET111    0
# S17       0
# S18       0
# S32       0
# S4        0
# SCOL      0
# SCR       0
# WER       0
# WOL       0
# WOX5      0
# Elong     0
# Mat       0
# Mer       0
# Wrt       0
# CHX       0
# MOCK      0
# dtype: int64

# %% [markdown]
# # Find True TF-targets mapping to gene_id

# %%
mapping_basic = {'miRNA165':'', 'Auxin':''}
found.head(5)
# Out:
#   Original_Gene locus_name symbol                         full_name
# 0           ACR  AT1G69040   ACR4               ACT domain repeat 4
# 1         Auxin
# 2           CLE  AT5G12990  CLE40           CLAVATA3/ESR-RELATED 40
# 3          IAA5  AT1G15580   IAA5  indole-3-acetic acid inducible 5
# 4           JKD  AT5G03150    JKD                           JACKDAW

# %%
found.rename(columns={'locus_name':'id'}, inplace=True)
mapping_unique = found.sort_values('symbol').groupby('Original_Gene').apply(lambda x: x.iloc[0])
mapping_unique = mapping_unique[mapping_unique.id!='']
mapping_unique
# Out:
#               Original_Gene         id symbol  \
# Original_Gene
# ACR                     ACR  AT1G69040   ACR4
# CLE                     CLE  AT5G12990  CLE40
# IAA5                   IAA5  AT1G15580   IAA5
# JKD                     JKD  AT5G03150    JKD
# MGP                     MGP  AT1G03840    MGP
# PHB                     PHB  AT2G34710    PHB
# SCR                     SCR  AT3G54220    SCR
# SHR                     SHR  AT4G37650    SHR
# WOX5                   WOX5  AT3G11260   WOX5
#
#                                       full_name
# Original_Gene
# ACR                         ACT domain repeat 4
# CLE                     CLAVATA3/ESR-RELATED 40
# IAA5           indole-3-acetic acid inducible 5
# JKD                                     JACKDAW
# MGP                                      Magpie
# PHB                                   PHABULOSA
# SCR                                   SCARECROW
# SHR                                  SHORT ROOT
# WOX5                 WUSCHEL related homeobox 5

# %%
# groups = merged.groupby('Original_Gene')
# std = groups.std()/data.std()
# std

# %% [markdown]
# # Gene in True network only

# %%
mapping_unique = mapping_unique[mapping_unique['Original_Gene'].isin(all_genes)]
mapping_unique
# Out:
#               Original_Gene         id symbol  \
# Original_Gene
# ACR                     ACR  AT1G69040   ACR4
# CLE                     CLE  AT5G12990  CLE40
# IAA5                   IAA5  AT1G15580   IAA5
# JKD                     JKD  AT5G03150    JKD
# MGP                     MGP  AT1G03840    MGP
# PHB                     PHB  AT2G34710    PHB
# SCR                     SCR  AT3G54220    SCR
# SHR                     SHR  AT4G37650    SHR
# WOX5                   WOX5  AT3G11260   WOX5
#
#                                       full_name
# Original_Gene
# ACR                         ACT domain repeat 4
# CLE                     CLAVATA3/ESR-RELATED 40
# IAA5           indole-3-acetic acid inducible 5
# JKD                                     JACKDAW
# MGP                                      Magpie
# PHB                                   PHABULOSA
# SCR                                   SCARECROW
# SHR                                  SHORT ROOT
# WOX5                 WUSCHEL related homeobox 5

# %%
pd.DataFrame(mapping_unique[['id', 'Original_Gene']].values, columns=['#ID', 'Name'])\
            .to_csv(final_gene_ids, sep='\t', index=False)
mapping_dic = dict(mapping_unique[['Original_Gene', 'id']].values)
mapping_dic
# Out:
# {'ACR': 'AT1G69040',
#  'CLE': 'AT5G12990',
#  'IAA5': 'AT1G15580',
#  'JKD': 'AT5G03150',
#  'MGP': 'AT1G03840',
#  'PHB': 'AT2G34710',
#  'SCR': 'AT3G54220',
#  'SHR': 'AT4G37650',
#  'WOX5': 'AT3G11260'}

# %% [markdown]
# # Save TF file

# %%
tf = true[0].unique()
tf_df = pd.DataFrame(tf)
tf_df.replace(mapping_basic, inplace=True)
tf_df.replace(mapping_dic, inplace=True)
tf_df = tf_df[tf_df[0]!='']
tf_df.dropna(inplace=True) # will remove missing genes
tf_df.to_csv(final_tf_file, header=False, index=False)
print(tf_df.shape)
tf_df
# Out:
# (9, 1)
#             0
# 0   AT1G03840
# 1   AT1G69040
# 2   AT5G03150
# 3   AT2G34710
# 4   AT1G15580
# 5   AT5G12990
# 6   AT4G37650
# 9   AT3G11260
# 10  AT3G54220

# %% [markdown]
# # Save True Egdes

# %%
true.replace(mapping_basic, inplace=True)
true.replace(mapping_dic, inplace=True)
true.dropna(inplace=True)
# true = true[true[0]!='']
true.to_csv(final_true_file_all, header=False, index=False, sep='\t')
print(true.shape)

true = true[true[0]!='']
true = true[true[1]!='']
true.to_csv(final_true_file, header=False, index=False, sep='\t')
print(true.shape)
true
# Out:
# (32, 3)
# (26, 3)
#             0          1    2
# 0   AT1G03840  AT4G37650  1.0
# 1   AT1G03840  AT5G03150  1.0
# 2   AT1G03840  AT1G03840 -1.0
# 3   AT1G03840  AT3G11260  1.0
# 4   AT1G69040  AT3G11260 -1.0
# 5   AT1G69040  AT2G34710 -1.0
# 6   AT5G03150  AT4G37650  1.0
# 7   AT5G03150  AT3G54220  1.0
# 8   AT5G03150  AT1G03840  1.0
# 9   AT5G03150  AT5G03150  1.0
# 10  AT2G34710  AT5G03150 -1.0
# 11  AT2G34710  AT2G34710  1.0
# 12  AT2G34710  AT3G11260 -1.0
# 13  AT1G15580  AT3G11260 -1.0
# 14  AT1G15580  AT2G34710  1.0
# 15  AT5G12990  AT3G11260 -1.0
# 16  AT5G12990  AT2G34710 -1.0
# 17  AT5G12990  AT5G12990  1.0
# 18  AT4G37650  AT3G54220  1.0
# 19  AT4G37650  AT4G37650  1.0
# 20  AT4G37650  AT2G34710  1.0
# 26  AT3G11260  AT3G11260  1.0
# 27  AT3G11260  AT1G15580  1.0
# 28  AT3G11260  AT2G34710  1.0
# 29  AT3G54220  AT3G54220  1.0
# 31  AT3G54220  AT5G03150  1.0

# %%
nt = pd.read_csv(final_paper_figure_table_original, header=None, sep='\t')
nt.replace(mapping_basic, inplace=True)
nt.replace(mapping_dic, inplace=True)
nt.dropna(inplace=True)
nt.to_csv(final_paper_figure_table_original[:-4]+'_mapped.csv', header=False, index=False, sep='\t')



nt = pd.read_csv(final_paper_figure_table_original, header=None, sep='\t')
nt.replace(mapping_basic, inplace=True)
nt.replace(mapping_dic, inplace=True)
nt.dropna(inplace=True)
nt.to_csv(final_paper_figure_table_original[:-4]+'_mapped.csv', header=False, index=False, sep='\t')

# %% [markdown]
# # Save expr data

# %%
print(mapping_unique.shape)
# merged = pd.merge(found,data, on='id', how='left')
merged = pd.merge(mapping_unique,data, on='id', how='left')
merged.fillna(0, inplace=True) #################
print(merged.shape)
merged


expr = merged.iloc[:, -22:]
expr['id'] = merged.id
expr.set_index('id', inplace=True)
expr = expr.T


expr.to_csv(final_expr_file, index=False, sep='\t')
expr.head()
# Out:
# (9, 4)
# (9, 26)
# id      AT1G69040  AT5G12990  AT1G15580  AT5G03150  AT1G03840  AT2G34710  \
# APL    101.133100   1.239030  12.325757   1.308202   4.261200  18.190900
# CO2    127.260333   1.573070  17.527267  46.552533  41.038533  10.496863
# COBL9   76.966433   0.309715  68.780700   0.289195   0.341962   0.719856
# COR     61.398700   0.000000  43.876633  49.190667   9.866630   1.056370
# E30     62.574067   0.000000   4.251477  20.341900   1.209761   3.926913
#
# id     AT3G54220  AT4G37650  AT3G11260
# APL     2.669827   7.251667   0.296092
# CO2    28.608967   1.424214   8.638093
# COBL9   2.416300   0.200322   0.060238
# COR    21.001567   0.387325  18.602100
# E30    96.338400   5.121557   1.796066

# %%
# mapping.shape

# %% [markdown]
# # Save Chip data

# %%
chip = pd.DataFrame(columns=sample_chip.columns)

for i in range(expr.shape[0]):
    chip.loc[i, :] = 'NA'
    chip.loc[i, 'Repeat'] = 1
    chip.loc[i, '#Experiment'] = i+1

chip.to_csv(final_chip_file, index=False, sep='\t')
chip
# Out:
#    #Experiment Perturbations PerturbationLevels Treatment DeletedGenes  \
# 0            1            NA                 NA        NA           NA
# 1            2            NA                 NA        NA           NA
# 2            3            NA                 NA        NA           NA
# 3            4            NA                 NA        NA           NA
# 4            5            NA                 NA        NA           NA
# 5            6            NA                 NA        NA           NA
# 6            7            NA                 NA        NA           NA
# 7            8            NA                 NA        NA           NA
# 8            9            NA                 NA        NA           NA
# 9           10            NA                 NA        NA           NA
# 10          11            NA                 NA        NA           NA
# 11          12            NA                 NA        NA           NA
# 12          13            NA                 NA        NA           NA
# 13          14            NA                 NA        NA           NA
# 14          15            NA                 NA        NA           NA
# 15          16            NA                 NA        NA           NA
# 16          17            NA                 NA        NA           NA
# 17          18            NA                 NA        NA           NA
# 18          19            NA                 NA        NA           NA
# 19          20            NA                 NA        NA           NA
# 20          21            NA                 NA        NA           NA
# 21          22            NA                 NA        NA           NA
#
#    OverexpressedGenes Time Repeat
# 0                  NA   NA      1
# 1                  NA   NA      1
# 2                  NA   NA      1
# 3                  NA   NA      1
# 4                  NA   NA      1
# 5                  NA   NA      1
# 6                  NA   NA      1
# 7                  NA   NA      1
# 8                  NA   NA      1
# 9                  NA   NA      1
# 10                 NA   NA      1
# 11                 NA   NA      1
# 12                 NA   NA      1
# 13                 NA   NA      1
# 14                 NA   NA      1
# 15                 NA   NA      1
# 16                 NA   NA      1
# 17                 NA   NA      1
# 18                 NA   NA      1
# 19                 NA   NA      1
# 20                 NA   NA      1
# 21                 NA   NA      1

# %% [markdown]
# # Results ---------------------

# %%
# results_file = 'paramsLog/paramFile_Root_2016-Nov-17_19-40.tsv_score.tsv'
results_file = 'paramsLog/paramFile_Root_2016-Nov-18_18-21.tsv_score.tsv'
score = pd.read_csv(results_file, sep='\t')
score.drop(['halfLife', 'scaleX', 'fit_intercept', 'l1_ratio', 'priorWeight', 'falsePriorRatio', 'priorFile'], axis=1, inplace=True)
print(score.shape)
# Out:
# (96, 9)

# %%
pd.options.display.max_rows = 200
score.sort_values(['priorPercent','aupr', 'method'])#.query('method=="FeatureScaling"')
# Out:
#                                              fileName  priorPercent     alpha  \
# 19  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 18  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 13  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.010000
# 12  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.010000
# 37  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.800000
# 36  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.800000
# 7   _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.001000
# 6   _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.001000
# 0   _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 51  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  9.168893
# 25  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.200000
# 24  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.200000
# 31  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.600000
# 30  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.600000
# 43  _priorPerct0_weight0.01__scaled__Nov-18_18-22-...             0  2.000000
# 42  _priorPerct0_weight0.01__scaled__Nov-18_18-22-...             0  2.000000
# 3   _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  9.168893
# 48  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 55  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.001000
# 61  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.010000
# 67  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 73  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.200000
# 79  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.600000
# 85  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.800000
# 91  _priorPerct0_weight0.01__scaled__Nov-18_18-22-...             0  2.000000
# 54  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.001000
# 60  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.010000
# 66  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.100000
# 72  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.200000
# 78  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.600000
# 84  _priorPerct0_weight0.01__scaled__Nov-18_18-21-...             0  0.800000
# 90  _priorPerct0_weight0.01__scaled__Nov-18_18-22-...             0  2.000000
# 21  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 20  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 15  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.010000
# 14  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.010000
# 39  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.800000
# 38  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.800000
# 9   _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.001000
# 8   _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.001000
# 1   _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 52  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  9.168893
# 27  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.200000
# 26  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.200000
# 33  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.600000
# 32  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.600000
# 45  _priorPerct50_weight0.01__scaled__Nov-18_18-22...            50  2.000000
# 44  _priorPerct50_weight0.01__scaled__Nov-18_18-22...            50  2.000000
# 4   _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  9.168893
# 49  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 57  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.001000
# 63  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.010000
# 69  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 75  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.200000
# 81  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.600000
# 87  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.800000
# 93  _priorPerct50_weight0.01__scaled__Nov-18_18-22...            50  2.000000
# 56  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.001000
# 62  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.010000
# 68  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.100000
# 74  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.200000
# 80  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.600000
# 86  _priorPerct50_weight0.01__scaled__Nov-18_18-21...            50  0.800000
# 92  _priorPerct50_weight0.01__scaled__Nov-18_18-22...            50  2.000000
# 23  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 22  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 17  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.010000
# 16  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.010000
# 41  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.800000
# 40  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.800000
# 11  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.001000
# 10  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.001000
# 2   _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 53  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  9.168893
# 29  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.200000
# 28  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.200000
# 35  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.600000
# 34  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.600000
# 47  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  2.000000
# 46  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  2.000000
# 5   _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  9.168893
# 50  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 59  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.001000
# 65  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.010000
# 71  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 77  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.200000
# 83  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.600000
# 89  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.800000
# 95  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  2.000000
# 58  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.001000
# 64  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.010000
# 70  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.100000
# 76  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.200000
# 82  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.600000
# 88  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  0.800000
# 94  _priorPerct100_weight0.01__scaled__Nov-18_18-2...           100  2.000000
#
#     isCV          method  freeCV  method_x     auroc      aupr
# 19     0  FeatureScaling       1   InfOnly  0.623457  0.624937
# 18     0  PenaltyScaling       1   InfOnly  0.623457  0.624937
# 13     0  FeatureScaling       1   InfOnly  0.648148  0.664628
# 12     0  PenaltyScaling       1   InfOnly  0.648148  0.664628
# 37     0  FeatureScaling       1   InfOnly  0.604938  0.665643
# 36     0  PenaltyScaling       1   InfOnly  0.604938  0.665643
# 7      0  FeatureScaling       1   InfOnly  0.645062  0.667068
# 6      0  PenaltyScaling       1   InfOnly  0.645062  0.667068
# 0      1  FeatureScaling       0   InfOnly  0.663580  0.674414
# 51     1  PenaltyScaling       1  Combined  0.581790  0.675694
# 25     0  FeatureScaling       1   InfOnly  0.638889  0.691404
# 24     0  PenaltyScaling       1   InfOnly  0.638889  0.691404
# 31     0  FeatureScaling       1   InfOnly  0.638889  0.698483
# 30     0  PenaltyScaling       1   InfOnly  0.638889  0.698483
# 43     0  FeatureScaling       1   InfOnly  0.669753  0.702871
# 42     0  PenaltyScaling       1   InfOnly  0.669753  0.702871
# 3      1  PenaltyScaling       1   InfOnly  0.668210  0.719692
# 48     1  FeatureScaling       0  Combined  0.555556  0.777778
# 55     0  FeatureScaling       1  Combined  0.555556  0.777778
# 61     0  FeatureScaling       1  Combined  0.555556  0.777778
# 67     0  FeatureScaling       1  Combined  0.555556  0.777778
# 73     0  FeatureScaling       1  Combined  0.555556  0.777778
# 79     0  FeatureScaling       1  Combined  0.555556  0.777778
# 85     0  FeatureScaling       1  Combined  0.555556  0.777778
# 91     0  FeatureScaling       1  Combined  0.555556  0.777778
# 54     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 60     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 66     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 72     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 78     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 84     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 90     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 21     0  FeatureScaling       1   InfOnly  0.623457  0.624937
# 20     0  PenaltyScaling       1   InfOnly  0.623457  0.624937
# 15     0  FeatureScaling       1   InfOnly  0.648148  0.664628
# 14     0  PenaltyScaling       1   InfOnly  0.648148  0.664628
# 39     0  FeatureScaling       1   InfOnly  0.604938  0.665643
# 38     0  PenaltyScaling       1   InfOnly  0.604938  0.665643
# 9      0  FeatureScaling       1   InfOnly  0.645062  0.667068
# 8      0  PenaltyScaling       1   InfOnly  0.645062  0.667068
# 1      1  FeatureScaling       0   InfOnly  0.663580  0.674414
# 52     1  PenaltyScaling       1  Combined  0.581790  0.675694
# 27     0  FeatureScaling       1   InfOnly  0.638889  0.691404
# 26     0  PenaltyScaling       1   InfOnly  0.638889  0.691404
# 33     0  FeatureScaling       1   InfOnly  0.638889  0.698483
# 32     0  PenaltyScaling       1   InfOnly  0.638889  0.698483
# 45     0  FeatureScaling       1   InfOnly  0.669753  0.702871
# 44     0  PenaltyScaling       1   InfOnly  0.669753  0.702871
# 4      1  PenaltyScaling       1   InfOnly  0.668210  0.719692
# 49     1  FeatureScaling       0  Combined  0.555556  0.777778
# 57     0  FeatureScaling       1  Combined  0.555556  0.777778
# 63     0  FeatureScaling       1  Combined  0.555556  0.777778
# 69     0  FeatureScaling       1  Combined  0.555556  0.777778
# 75     0  FeatureScaling       1  Combined  0.555556  0.777778
# 81     0  FeatureScaling       1  Combined  0.555556  0.777778
# 87     0  FeatureScaling       1  Combined  0.555556  0.777778
# 93     0  FeatureScaling       1  Combined  0.555556  0.777778
# 56     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 62     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 68     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 74     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 80     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 86     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 92     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 23     0  FeatureScaling       1   InfOnly  0.623457  0.624937
# 22     0  PenaltyScaling       1   InfOnly  0.623457  0.624937
# 17     0  FeatureScaling       1   InfOnly  0.648148  0.664628
# 16     0  PenaltyScaling       1   InfOnly  0.648148  0.664628
# 41     0  FeatureScaling       1   InfOnly  0.604938  0.665643
# 40     0  PenaltyScaling       1   InfOnly  0.604938  0.665643
# 11     0  FeatureScaling       1   InfOnly  0.645062  0.667068
# 10     0  PenaltyScaling       1   InfOnly  0.645062  0.667068
# 2      1  FeatureScaling       0   InfOnly  0.663580  0.674414
# 53     1  PenaltyScaling       1  Combined  0.581790  0.675694
# 29     0  FeatureScaling       1   InfOnly  0.638889  0.691404
# 28     0  PenaltyScaling       1   InfOnly  0.638889  0.691404
# 35     0  FeatureScaling       1   InfOnly  0.638889  0.698483
# 34     0  PenaltyScaling       1   InfOnly  0.638889  0.698483
# 47     0  FeatureScaling       1   InfOnly  0.669753  0.702871
# 46     0  PenaltyScaling       1   InfOnly  0.669753  0.702871
# 5      1  PenaltyScaling       1   InfOnly  0.668210  0.719692
# 50     1  FeatureScaling       0  Combined  0.555556  0.777778
# 59     0  FeatureScaling       1  Combined  0.555556  0.777778
# 65     0  FeatureScaling       1  Combined  0.555556  0.777778
# 71     0  FeatureScaling       1  Combined  0.555556  0.777778
# 77     0  FeatureScaling       1  Combined  0.555556  0.777778
# 83     0  FeatureScaling       1  Combined  0.555556  0.777778
# 89     0  FeatureScaling       1  Combined  0.555556  0.777778
# 95     0  FeatureScaling       1  Combined  0.555556  0.777778
# 58     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 64     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 70     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 76     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 82     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 88     0  PenaltyScaling       1  Combined  0.555556  0.777778
# 94     0  PenaltyScaling       1  Combined  0.555556  0.777778

# %%
score.iloc[47].fileName
# Out:
# '_priorPerct100_weight0.01__scaled__Nov-18_18-22--03FeatureScaling'
